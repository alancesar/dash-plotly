# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/alancesar/anaconda3
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.7.22          |  py311hca03da5_0         155 KB
#     conda-23.7.2               |  py311hca03da5_0         1.3 MB
#     jupyter_client-7.4.9       |  py311hca03da5_0         263 KB
#     jupyter_server-1.23.4      |  py311hca03da5_0         447 KB
#     openssl-1.1.1v             |       h1a28f6b_0         2.6 MB
#     pyzmq-23.2.0               |  py311h313beb8_0         497 KB
#     ------------------------------------------------------------
#                                            Total:         5.3 MB
#
# The following packages will be UPDATED:
#
#   certifi                          2023.5.7-py311hca03da5_0 --> 2023.7.22-py311hca03da5_0
#   conda                              23.5.2-py311hca03da5_0 --> 23.7.2-py311hca03da5_0
#   openssl                                 1.1.1u-h1a28f6b_0 --> 1.1.1v-h1a28f6b_0
#
# The following packages will be DOWNGRADED:
#
#   jupyter_client                      8.1.0-py311hca03da5_0 --> 7.4.9-py311hca03da5_0
#   jupyter_server                      2.5.0-py311hca03da5_0 --> 1.23.4-py311hca03da5_0
#   pyzmq                              25.1.0-py311h313beb8_0 --> 23.2.0-py311h313beb8_0
#
#
#
# Downloading and Extracting Packages
# jupyter_server-1.23. | 447 KB    |                                       |   0%
# certifi-2023.7.22    | 155 KB    |                                       |   0%
#
# conda-23.7.2         | 1.3 MB    |                                       |   0%
#
#
# pyzmq-23.2.0         | 497 KB    |                                       |   0%
#
#
#
# jupyter_client-7.4.9 | 263 KB    |                                       |   0%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    |                                       |   0%
#
# jupyter_server-1.23. | 447 KB    | #3                                    |   4%
#
#
# pyzmq-23.2.0         | 497 KB    | #1                                    |   3%
# certifi-2023.7.22    | 155 KB    | ###8                                  |  10%
#
#
#
# jupyter_client-7.4.9 | 263 KB    | ##2                                   |   6%
#
# conda-23.7.2         | 1.3 MB    | ########7                             |  24%
# certifi-2023.7.22    | 155 KB    | ###############2                      |  41%
#
#
# jupyter_server-1.23. | 447 KB    | #########2                            |  25%
#
#
#
# jupyter_client-7.4.9 | 263 KB    | ###########2                          |  30%
#
# conda-23.7.2         | 1.3 MB    | ###################6                  |  53%
#
#
# pyzmq-23.2.0         | 497 KB    | #################8                    |  48%
# certifi-2023.7.22    | 155 KB    | ##################################### | 100%
# certifi-2023.7.22    | 155 KB    | ##################################### | 100%
#
#
#
# jupyter_server-1.23. | 447 KB    | ######################5               |  61%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    | 2                                     |   1%
#
#
#
# jupyter_client-7.4.9 | 263 KB    | ##################################### | 100%
#
#
#
#
# jupyter_server-1.23. | 447 KB    | ##################################### | 100%
#
#
# pyzmq-23.2.0         | 497 KB    | ##################################### | 100%
#
#
# pyzmq-23.2.0         | 497 KB    | ##################################### | 100%
#
# conda-23.7.2         | 1.3 MB    | ##################################### | 100%
#
# conda-23.7.2         | 1.3 MB    | ##################################### | 100%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    | ########7                             |  24%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    | ##############8                       |  40%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    | ##########################6           |  72%
#
#
#
#
# openssl-1.1.1v       | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install --yes --prefix {sys.prefix} dash
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/alancesar/anaconda3
#
#   added / updated specs:
#     - dash
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |  py311h313beb8_7         321 KB
#     dash-2.7.0                 |  py311hca03da5_0         6.0 MB
#     flask-compress-1.13        |  py311hca03da5_0          21 KB
#     ------------------------------------------------------------
#                                            Total:         6.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/osx-arm64::brotli-python-1.0.9-py311h313beb8_7
#   dash               pkgs/main/osx-arm64::dash-2.7.0-py311hca03da5_0
#   flask-compress     pkgs/main/osx-arm64::flask-compress-1.13-py311hca03da5_0
#
#
#
# Downloading and Extracting Packages
# flask-compress-1.13  | 21 KB     |                                       |   0%
# dash-2.7.0           | 6.0 MB    |                                       |   0%
#
# flask-compress-1.13  | 21 KB     | ###########################5          |  75%
# dash-2.7.0           | 6.0 MB    |                                       |   0%
#
# flask-compress-1.13  | 21 KB     | ##################################### | 100%
# dash-2.7.0           | 6.0 MB    | #9                                    |   5%
#
# brotli-python-1.0.9  | 321 KB    | #########################7            |  70%
#
# brotli-python-1.0.9  | 321 KB    | ##################################### | 100%
# dash-2.7.0           | 6.0 MB    | ####                                  |  11%
# dash-2.7.0           | 6.0 MB    | ########4                             |  23%
# dash-2.7.0           | 6.0 MB    | #############7                        |  37%
# dash-2.7.0           | 6.0 MB    | #####################4                |  58%
# dash-2.7.0           | 6.0 MB    | ##########################5           |  72%
# dash-2.7.0           | 6.0 MB    | ##################################7   |  94%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from dash import Dash, html

app = Dash(__name__)
app.layout = html.Div("Hello!")

if __name__ == "__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_7_0m1677970696.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/deps/react@16.v2_7_0m1677970696.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_7_0m1677970696.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_7_0m1677970696.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_7_0m1677970696.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_7_0m1677970696.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_7_0m1677970696.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_0m1677970696.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_6m1677970696.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2023 19:02:05] "GET /_favicon.ico?v=2.7.0 HTTP/1.1" 200 -
